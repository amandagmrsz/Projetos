# %% [markdown]
# <a href="https://colab.research.google.com/github/amandagmrsz/Projetos/blob/main/Investimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def MenuFinanceiro():
    while True:
        print("\n         ===== <<< FINANCEIRO >>> =====")
        print("         | [1] Monitoramento de Gastos |")
        print("         | [2] Holerite                |")
        print("         | [3] Investimentos           |")
        print("         | [0] Sair                    |")
        print("         ------------------------------")
        opcao = input("Insira a opção: ")

        if opcao == "1":
            print("\nVocê escolheu a opção: IRPF\n")
            print("Em breve!")
        elif opcao == "2":
            print("\nVocê escolheu a opção: Cálculo Trabalhista\n")
            print("Em breve!")
        elif opcao == "3":
            print("\nVocê escolheu a opção: Investimentos\n")
            SimuladorInvestimentos()
        elif opcao == "0":
            print("Saindo do sistema...")
            break
        else:
            print("\nOpção inválida! Tente novamente.\n")

def SimuladorInvestimentos():
    Nome = str(input("Qual seu nome: ")).title()
    IdadeAtual = int(input("Qual sua idade atual: "))

    print("\nEscolha o nível de risco para seus investimentos:")
    print("1. Baixo Risco (SELIC)")
    print("2. Médio Risco (CDB)")
    print("3. Alto Risco (BITCOIN)")
    Risco = input("Digite o número da opção escolhida: ")

    if Risco == "1":
        TaxaAnuais = 0.02
        Investimentos = [
            {"nome": "MRFG11", "tipo": "Fundo de Renda Fixa", "rentabilidade": 5.0},
            {"nome": "HGLG11", "tipo": "Fundo Imobiliário", "rentabilidade": 8.0},
            {"nome": "TRXF11", "tipo": "Fundo de Renda Fixa", "rentabilidade": 4.5}
        ]
    elif Risco == "2":
        TaxaAnuais = 0.05
        Investimentos = [
            {"nome": "MRFX11", "tipo": "Fundo Multimercado", "rentabilidade": 10.0},
            {"nome": "XFIX11", "tipo": "Fundo de Renda Fixa", "rentabilidade": 7.0},
            {"nome": "BCFF11", "tipo": "Fundo de Fundos", "rentabilidade": 9.0}
        ]
    elif Risco == "3":
        TaxaAnuais = 0.10
        Investimentos = [
            {"nome": "XPML11", "tipo": "Fundo Imobiliário", "rentabilidade": 12.5},
            {"nome": "VTIQ11", "tipo": "Fundo de Tecnologia", "rentabilidade": 15.0},
            {"nome": "GGRC11", "tipo": "Fundo de Renda Imobiliária", "rentabilidade": 11.0}
        ]
    else:
        print("Opção inválida!")
        return  # Termina a função sem continuar

    # Imprime o cabeçalho da tabela
    print(f"\n{'Nome do Investimento':<25}{'Tipo de Investimento':<35}{'Rentabilidade (%)':<20}")
    print("-" * 70)

    # Imprime os dados de cada investimento a partir da lista armazenada
    for investimento in Investimentos:
        print(f"{investimento['nome']:<25}{investimento['tipo']:<35}{investimento['rentabilidade']:<20.2f}")

    ValorMensalInvestido = float(input("\nQuanto você pode investir por mês? R$: "))
    Meses = int(input("Por quantos meses você pretende investir? "))

    TaxaMensal = TaxaAnuais / 12
    MontanteFinal = 0

    for x in range(Meses):
        MontanteFinal = (MontanteFinal + ValorMensalInvestido) * (1 + TaxaMensal)

    TotalInvestido = ValorMensalInvestido * Meses
    Rendimento = MontanteFinal - TotalInvestido

    print(f"\nOlá, {Nome}! Aqui estão os resultados da sua simulação:")
    print(f"Valor total investido: R$ {TotalInvestido:.2f}")
    print(f"Valor final após {Meses} meses: R$ {MontanteFinal:.2f}")
    print(f"Rendimento total: R$ {Rendimento:.2f}")

def MonitoramentoGatos():
    import pandas as pd
  # Lista de meses
  meses = ["Janeiro", "Fevereiro", "Março", "Abril", "Maio", "Junho",
          "Julho", "Agosto", "Setembro", "Outubro", "Novembro", "Dezembro"]

  # Estrutura de categorias e subcategorias financeiras
  dados = {
      "RECEITAS": ["Salário", "Aluguel", "Pensão", "Horas extras", "13º salário", "Férias", "Rendimentos", "Outros"],
      "INVESTIMENTOS": ["Ações", "Tesouro Direto", "Renda fixa", "Previdência privada", "Outros"],

      "DESPESAS FIXAS": ["Habitação", "Transporte", "Saúde", "Educação", "Imposto", "Outros"],
      "Habitação": ["Aluguel", "Condomínio", "Prestação da casa", "Seguro da casa", "Diarista"],
      "Transporte": ["Pestação do carro", "Seguro do Carro"],
      "Saúde": ["Plano Saúde", "Seguro Saúde"],
      "Educação": ["Colégio", "Faculdade", "Cursos"],
      "Imposto": ["IPTU", "IPVA"],
      "Outros": ["Empréstimos", "Seguro de Vida"],

      "DESPESAS VARIÁVEIS": ["Habitação", "Transporte", "Alimentação", "Saúde", "Cuidados Pessoais"],
      "Habitação": ["Luz", "Água", "Telefone", "Gás", "Tv e Streaming", "Internet"],
      "Transporte": ["Metrô", "Ônibus", "Uber e Táxi", "Combustível", "Estacionamento"],
      "Alimentação": ["Super Mercado", "Feira", "Padaria", "Delivery"],
      "Saúde": ["Medicamentos"],
      "Cuidados Pessoais": ["Cabelereiro", "Manicure", "Esteticista", "Academia", "Clube"],

      "DESPESAS EXTRAS": ["Médico", "Dentista", "Hospital","Carro (manutenção)", "Casa (manutenção)", "Material escolar", "Uniforme"],
      "DESPESAS ADICIONAIS": ["Viagens", "Cinema/Tratro", "Roupas", "Calçados", "Restaurantes/Bares", "Presentes", "Acessórios", "Outros"]
  }

  # Criar DataFrames para cada categoria com subcategorias e meses
  tabelas = {}
  for categoria, subcategorias in dados.items():
      tabelas[categoria] = pd.DataFrame({
          "Subcategoria": subcategorias,
          **{mes: [0] * len(subcategorias) for mes in meses},  # Inicializa com zeros
          "Total Anual": [0] * len(subcategorias),
          "Média Mensal": [0] * len(subcategorias),
      })

  # Função para calcular totais e médias
  def calcular_totais(df):
      df["Total Anual"] = df[meses].sum(axis=1)
      df["Média Mensal"] = df[meses].mean(axis=1)
      return df

  # Preenchimento de valores por mês
  def preencher_mes(tabelas, mes_idx):
      mes_atual = meses[mes_idx]
      print(f"\nPreenchendo dados para o mês de {mes_atual}:")
      for categoria, tabela in tabelas.items():
          print(f"\nCategoria: {categoria}")
          for i, row in tabela.iterrows():
              subcategoria = row["Subcategoria"]
              while True:
                  try:
                      valor = float(input(f"Digite o valor para {subcategoria} ({categoria}): "))
                      tabelas[categoria].at[i, mes_atual] = valor
                      break
                  except ValueError:
                      print("Por favor, insira um valor numérico válido.")
      return tabelas

  # Cálculo do saldo total (mensal ou anual)
  def calcular_saldos(tabelas):
      total_receitas = tabelas["RECEITAS"]["Total Anual"].sum()
      total_investimentos = tabelas["INVESTIMENTOS"]["Total Anual"].sum()
      total_despesas = sum(
          tabelas[cat]["Total Anual"].sum()
          for cat in ["DESPESAS FIXAS", "DESPESAS VARIÁVEIS", "DESPESAS EXTRAS", "DESPESAS ADICIONAIS"]
      )
      saldo = total_receitas - (total_investimentos + total_despesas)
      return total_receitas, total_investimentos, total_despesas, saldo

  # Preencher os dados mês a mês
  for mes_idx in range(len(meses)):
      tabelas = preencher_mes(tabelas, mes_idx)
      for categoria in tabelas:
          tabelas[categoria] = calcular_totais(tabelas[categoria])

      # Resumo mensal
      print("\nResumo do mês:")
      total_receitas, total_investimentos, total_despesas, saldo = calcular_saldos(tabelas)
      print(f"Receitas: R$ {total_receitas:.2f}")
      print(f"Investimentos: R$ {total_investimentos:.2f}")
      print(f"Despesas: R$ {total_despesas:.2f}")
      print(f"Saldo: R$ {saldo:.2f}")

  # Cálculo de totais anuais
  print("\nResumo Anual:")
  total_receitas, total_investimentos, total_despesas, saldo = calcular_saldos(tabelas)
  print(f"Total Receitas: R$ {total_receitas:.2f}")
  print(f"Total Investimentos: R$ {total_investimentos:.2f}")
  print(f"Total Despesas: R$ {total_despesas:.2f}")
  print(f"Saldo Final: R$ {saldo:.2f}")

  # Exibir as tabelas completas
  for categoria, tabela in tabelas.items():
      print(f"\nCategoria: {categoria}")
      print(tabela)

# Chama o menu financeiro
MenuFinanceiro()
# Out:
#          ===== <<< FINANCEIRO >>> =====
#          | [1] IRPF                    |
#          | [2] Cálculo Trabalhista     |
#          | [3] Investimentos           |
#          | [0] Sair                    |
#          ------------------------------
# Insira a opção: 1
#
# Você escolheu a opção: IRPF
#
# Em breve!
#
#          ===== <<< FINANCEIRO >>> =====
#          | [1] IRPF                    |
#          | [2] Cálculo Trabalhista     |
#          | [3] Investimentos           |
#          | [0] Sair                    |
#          ------------------------------
# Insira a opção: 2
#
# Você escolheu a opção: Cálculo Trabalhista
#
# Em breve!
#
#          ===== <<< FINANCEIRO >>> =====
#          | [1] IRPF                    |
#          | [2] Cálculo Trabalhista     |
#          | [3] Investimentos           |
#          | [0] Sair                    |
#          ------------------------------
# Insira a opção: 3
#
# Você escolheu a opção: Investimentos
#
# ...

# %%
def MenuFinanceiro():
    while True:
        print("\n         ===== <<< FINANCEIRO >>> =====")
        print("         | [1] IRPF                    |")
        print("         | [2] Cálculo Trabalhista     |")
        print("         | [3] Investimentos           |")
        print("         | [0] Sair                    |")
        print("         ------------------------------")
        opcao = input("Insira a opção: ")

        if opcao == "1":
            print("\nVocê escolheu a opção: IRPF\n")
            print("Em breve!")
        elif opcao == "2":
            print("\nVocê escolheu a opção: Cálculo Trabalhista\n")
            print("Em breve!")
        elif opcao == "3":
            print("\nVocê escolheu a opção: Investimentos\n")
            SimuladorInvestimentos()
        elif opcao == "0":
            print("Saindo do sistema...")
            break
        else:
            print("\nOpção inválida! Tente novamente.\n")

# %%
print("O tipo de investimento escolhido foi Baixo Risco.")
print("\nO que é investimento de BAIXO RISCO:")
print('''Investimentos de BAIXO RISCO são aplicações com uma baixa probabilidade de perda de valor.
Eles são uma boa opção para quem está começando a investir, pois o risco de prejuízo é menor.''')

print('''Tipos de Investimentos de BAIXO RISCO:
1. Recibo de Depósito Cooperativo (RDC)
2. Fundos de renda fixa
3. Letras de Crédito Imobiliário e do Agronegócio (LCI e LCA)
4. Tesouro Selic
5. Fundos DI
6. CDBs
7. Poupança (opção clássica e segura para iniciantes)''')

print("\nRelatório")
print("\nRisco: ")
print("\nRentabilidade: ")
print("\nImposto de Renda:")
print("\nCome Cotas: ")
print("\nIOF: ")
print("\nInvestimento: ")
print("\nResgate: ")


# RDC
print("\n2. Recibo de Depósito Cooperativo (RDC)")
print("Risco: Baixo.")
print("Rentabilidade: Pode ser atrelada ao CDI.")
print("Imposto de Renda: Tributada conforme tabela regressiva.")
print("Come Cotas: Não se aplica.")
print("IOF: Aplicável se resgatar antes de 30 dias.")
print("Investimento: Varia conforme a instituição.")
print("Resgate: Conforme o contrato.")

# Fundos de Renda Fixa
print("\n3. Fundos de Renda Fixa")
print("Risco: Baixo, mas depende da qualidade dos ativos.")
print("Rentabilidade: Geralmente atrelada ao CDI ou à Selic.")
print("Imposto de Renda: Tributada conforme tabela regressiva.")
print("Come Cotas: Aplicável semestralmente.")
print("IOF: Aplicável se resgatar antes de 30 dias.")
print("Investimento: Mínimo varia entre R$ 100 a R$ 1.000.")
print("Resgate: Prazo varia conforme o fundo.")

# LCI e LCA
print("\n4. Letras de Crédito Imobiliário e do Agronegócio (LCI e LCA)")
print("Risco: Baixo, garantidas por lastro imobiliário ou do agronegócio.")
print("Rentabilidade: Geralmente atrelada ao CDI e isentas de IR.")
print("Imposto de Renda: Isentas de IR.")
print("Come Cotas: Não se aplica.")
print("IOF: Aplicável se resgatar antes de 30 dias.")
print("Investimento: Varia conforme a instituição, geralmente a partir de R$ 1.000.")
print("Resgate: Geralmente tem prazo de carência.")
# Out:
# O tipo de investimento escolhido foi Baixo Risco.
#
# O que é investimento de BAIXO RISCO:
# Investimentos de BAIXO RISCO são aplicações com uma baixa probabilidade de perda de valor.
# Eles são uma boa opção para quem está começando a investir, pois o risco de prejuízo é menor.
#
# Relatório
#
#
# 1. Recibo de Depósito Cooperativo (RDC)
# 2. Fundos de renda fixa
# 3. Letras de Crédito Imobiliário e do Agronegócio (LCI e LCA)
# 4. Tesouro Selic
# 5. Fundos DI
# 6. CDBs

# %%
def BaixoRisco():
    print("\033[1mO tipo de investimento escolhido foi Baixo Risco.")
    print("\nO que é investimento de BAIXO RISCO:")
    print('''Investimentos de BAIXO RISCO são aplicações com uma baixa probabilidade de perda de valor.
Eles são uma boa opção para quem está começando a investir, pois o risco de prejuízo é menor.''')

    print("\nTipos de Investimentos de BAIXO RISCO:")

# Poupança
    print("\n1. Poupança")
    print("Risco: Baixo.")
    print("Rentabilidade: Geralmente 70% da taxa Selic(atualmente em 11,25% ao ano) com rendimento mensal.")
    print("Imposto de Renda: Isenta de IR.")
    print("Come Cotas: Não se aplica.")
    print("IOF: Isenta de IOF.")
    print("Investimento: A partir de R$ 1.")
    print("Resgate: Liquidez diária.")

# Tesouro Selic
    print("\n2. Tesouro Selic")
    print("Risco: Baixo, com garantia do governo federal.")
    print("Rentabilidade: Atrelada à taxa Selic, atualmente em 11,25% ao ano.")
    print("Imposto de Renda: Tributada conforme tabela regressiva (de 22,5% a 15%).")
    print("Come Cotas: Não se aplica.")
    print("IOF: Aplicável se resgatar antes de 30 dias.")
    print("Investimento: A partir de R$ 30.")
    print("Resgate: Varia conforme o título.")

# Fundos DI
    print("\n3. Fundos DI")
    print("Risco: Baixo, investe principalmente em títulos públicos e privados.")
    print("Rentabilidade: Geralmente atrelada ao CDI, atualmente em 10,65% ao ano.")
    print("Imposto de Renda: Tributada conforme tabela regressiva (de 22,5% a 15%).")
    print("Come Cotas: Aplicável semestralmente.")
    print("IOF: Aplicável se resgatar antes de 30 dias.")
    print("Investimento: Mínimo varia entre R$ 100 a R$ 1.000.")
    print("Resgate: Prazo varia conforme o fundo.")

BaixoRisco()
# Out:
# O tipo de investimento escolhido foi Baixo Risco.
#
# O que é investimento de BAIXO RISCO:
# Investimentos de BAIXO RISCO são aplicações com uma baixa probabilidade de perda de valor.
# Eles são uma boa opção para quem está começando a investir, pois o risco de prejuízo é menor.
#
# Tipos de Investimentos de BAIXO RISCO:
#
# 1. Poupança
# Risco: Baixo.
# Rentabilidade: Geralmente 70% da taxa Selic(atualmente em 11,25% ao ano) com rendimento mensal.
# Imposto de Renda: Isenta de IR.
# Come Cotas: Não se aplica.
# IOF: Isenta de IOF.
# Investimento: A partir de R$ 1.
# Resgate: Liquidez diária.
#
# 2. Tesouro Selic
# Risco: Baixo, com garantia do governo federal.
# Rentabilidade: Atrelada à taxa Selic, atualmente em 11,25% ao ano.
# Imposto de Renda: Tributada conforme tabela regressiva (de 22,5% a 15%).
# Come Cotas: Não se aplica.
# IOF: Aplicável se resgatar antes de 30 dias.
# Investimento: A partir de R$ 30.
# Resgate: Varia conforme o título.
#
# 3. Fundos DI
# ...
